# %%
import snowflake.connector

# Replace these with your Snowflake account details
snowflake_account = 'your_account_url'
snowflake_user = 'your_username'
snowflake_password = 'your_password'
snowflake_database = 'your_database'
snowflake_schema = 'your_schema'

# Establish a connection to Snowflake
conn = snowflake.connector.connect(
    user=snowflake_user,
    password=snowflake_password,
    account=snowflake_account,
    database=snowflake_database,
    schema=snowflake_schema
)

# Create a cursor to execute SQL queries
cursor = conn.cursor()

# Execute SQL queries
cursor.execute('SELECT * FROM your_table')
results = cursor.fetchall()
for row in results:
    print(row)

# Close the cursor and connection when done
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ForbiddenError                            Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/auth/_auth.py:250, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     249 try:
# --> 250     ret = self._rest._post_request(
#     251         url,
#     252         headers,
#     253         json.dumps(body),
#     254         timeout=auth_timeout,
#     255         socket_timeout=auth_timeout,
#     256     )
#     257 except ForbiddenError as err:
#     258     # HTTP 403
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/network.py:730, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, _no_results, no_retry, socket_timeout, _include_retry_params)
#     728     pprint(ret)
# --> 730 ret = self.fetch(
#     731     "post",
#     732     full_url,
#     733     headers,
#     734     data=body,
#     735     timeout=timeout,
#     736     token=token,
#     737     no_retry=no_retry,
#     738     socket_timeout=socket_timeout,
#     739     _include_retry_params=_include_retry_params,
#     740 )
#     741 logger.debug(
#     742     "ret[code] = {code}, after post request".format(
#     743         code=(ret.get("code", "N/A"))
#     744     )
#     745 )
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/network.py:849, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     848 while True:
# --> 849     ret = self._request_exec_wrapper(
#     850         session, method, full_url, headers, data, retry_ctx, **kwargs
#     851     )
#     852     if ret is not None:
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/network.py:987, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     986 if not no_retry:
# --> 987     raise e
#     988 logger.debug("Ignored error", exc_info=True)
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/network.py:891, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     890 try:
# --> 891     return_object = self._request_exec(
#     892         session=session,
#     893         method=method,
#     894         full_url=full_url,
#     895         headers=headers,
#     896         data=data,
#     897         token=token,
#     898         **kwargs,
#     899     )
#     900     if return_object is not None:
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/network.py:1189, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication)
#    1180 TelemetryService.get_instance().log_http_request_error(
#    1181     "HttpException%s" % str(err),
#    1182     full_url,
#    (...)
#    1187     stack_trace=traceback.format_exc(),
#    1188 )
# -> 1189 raise err
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/network.py:1110, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication)
#    1109 if is_login_request(full_url) and raw_ret.status_code == FORBIDDEN:
# -> 1110     raise ForbiddenError
#    1112 elif is_retryable_http_code(raw_ret.status_code):
#
# ForbiddenError: HTTP 403: Forbidden
#
# During handling of the above exception, another exception occurred:
#
# ForbiddenError                            Traceback (most recent call last)
# Cell In[1], line 11
#       8 snowflake_schema = 'your_schema'
#      10 # Establish a connection to Snowflake
# ---> 11 conn = snowflake.connector.connect(
#      12     user=snowflake_user,
#      13     password=snowflake_password,
#      14     account=snowflake_account,
#      15     database=snowflake_database,
#      16     schema=snowflake_schema
#      17 )
#      19 # Create a cursor to execute SQL queries
#      20 cursor = conn.cursor()
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/__init__.py:54, in Connect(**kwargs)
#      52 @wraps(SnowflakeConnection.__init__)
#      53 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 54     return SnowflakeConnection(**kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/connection.py:381, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     377 self._server_use_nanoarrow_converter_parameter = True
#     378 self._create_pyarrow_iterator_method = (
#     379     snowflake.connector.result_batch._create_nanoarrow_iterator
#     380 )
# --> 381 self.connect(**kwargs)
#     382 self._telemetry = TelemetryClient(self._rest)
#     384 # get the imported modules from sys.modules
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/connection.py:653, in SnowflakeConnection.connect(self, **kwargs)
#     651         connection_diag.generate_report()
#     652 else:
# --> 653     self.__open_connection()
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/connection.py:926, in SnowflakeConnection.__open_connection(self)
#     922 else:
#     923     # okta URL, e.g., https://<account>.okta.com/
#     924     self.auth_class = AuthByOkta(application=self.application)
# --> 926 self.authenticate_with_retry(self.auth_class)
#     928 self._password = None  # ensure password won't persist
#     929 self.auth_class.reset_secrets()
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/connection.py:1211, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1208 def authenticate_with_retry(self, auth_instance) -> None:
#    1209     # make some changes if needed before real __authenticate
#    1210     try:
# -> 1211         self._authenticate(auth_instance)
#    1212     except ReauthenticationRequest as ex:
#    1213         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1214         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/connection.py:1237, in SnowflakeConnection._authenticate(self, auth_instance)
#    1235 auth = Auth(self.rest)
#    1236 try:
# -> 1237     auth.authenticate(
#    1238         auth_instance=auth_instance,
#    1239         account=self.account,
#    1240         user=self.user,
#    1241         database=self.database,
#    1242         schema=self.schema,
#    1243         warehouse=self.warehouse,
#    1244         role=self.role,
#    1245         passcode=self._passcode,
#    1246         passcode_in_password=self._passcode_in_password,
#    1247         mfa_callback=self._mfa_callback,
#    1248         password_callback=self._password_callback,
#    1249         session_parameters=self._session_parameters,
#    1250     )
#    1251 except OperationalError as e:
#    1252     logger.debug(
#    1253         "Operational Error raised at authentication"
#    1254         f"for authenticator: {type(auth_instance).__name__}"
#    1255     )
#
# File /usr/local/lib/python3.10/dist-packages/snowflake/connector/auth/_auth.py:259, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     250     ret = self._rest._post_request(
#     251         url,
#     252         headers,
#    (...)
#     255         socket_timeout=auth_timeout,
#     256     )
#     257 except ForbiddenError as err:
#     258     # HTTP 403
# --> 259     raise err.__class__(
#     260         msg=(
#     261             "Failed to connect to DB. "
#     262             "Verify the account name is correct: {host}:{port}. "
#     263             "{message}"
#     264         ).format(
#     265             host=self._rest._host, port=self._rest._port, message=str(err)
#     266         ),
#     267         errno=ER_FAILED_TO_CONNECT_TO_DB,
#     268         sqlstate=SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     269     )
#     270 except (ServiceUnavailableError, BadGatewayError) as err:
#     271     # HTTP 502/504
#     272     raise err.__class__(
#     273         msg=(
#     274             "Failed to connect to DB. "
#    (...)
#     281         sqlstate=SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     282     )
#
# ForbiddenError: 250001 (08001): Failed to connect to DB. Verify the account name is correct: your_account_url.snowflakecomputing.com:443. HTTP 403: Forbidden
